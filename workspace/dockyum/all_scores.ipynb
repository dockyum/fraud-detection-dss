# %%
import pandas as pd

df1 = pd.read_csv('../../datas/borderlineSMOTE_classweight_result.csv', index_col=0)
df2 = pd.read_csv('../../datas/borderlineSMOTE_result.csv', index_col=0)
df3 = pd.read_csv('../../datas/SMOTE_and_ADASYN_classweight_result.csv', index_col=0)
df4 = pd.read_csv('../../datas/SVMSMOTE_ROS_results.csv', index_col=0)
df5 = pd.read_csv('../../datas/SVMSMOTE_ROS_classweight_result.csv', index_col=0)
df6 = pd.read_csv('../../datas/SVMSMOTE_ROS_results.csv', index_col=0)

df = pd.concat([df1,df2,df3,df4, df5, df6])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 790 entries, 0 to SVC
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   class_weight     230 non-null    object
#  1   null_del         790 non-null    float64
#  2   encoded          790 non-null    float64
#  3   scaler           790 non-null    object
#  4   sampler          790 non-null    object
#  5   classifier       320 non-null    object
#  6   train accuracy   790 non-null    float64
#  7   train precision  790 non-null    float64
#  8   train recall     790 non-null    float64
#  9   train f1         790 non-null    float64
#  10  train auc        790 non-null    float64
#  11  test accuracy    790 non-null    float64
#  12  test precision   790 non-null    float64
#  13  test recall      790 non-null    float64
#  14  test f1          790 non-null    float64
#  15  test auc         790 non-null    float64
# dtypes: float64(12), object(4)
# ...

# %%
df = df.drop(columns='Unnamed: 0')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 34
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   null_del         400 non-null    float64
#  1   encoded          435 non-null    float64
#  2   scaler           435 non-null    object
#  3   sampler          435 non-null    object
#  4   classifier       435 non-null    object
#  5   train accuracy   435 non-null    float64
#  6   train precision  435 non-null    float64
#  7   train recall     435 non-null    float64
#  8   train f1         435 non-null    float64
#  9   train auc        435 non-null    float64
#  10  test accuracy    435 non-null    float64
#  11  test precision   435 non-null    float64
#  12  test recall      435 non-null    float64
#  13  test f1          435 non-null    float64
#  14  test auc         435 non-null    float64
#  15  PCA              35 non-null     float64
# dtypes: float64(13), object(3)
# ...

# %%
df.head()
# Out:
#   class_weight  null_del  encoded scaler   sampler    classifier  \
# 0            1       1.0      1.0   None  BdlSMOTE   LogisticReg
# 1            1       1.0      1.0   None  BdlSMOTE  DecisionTree
# 2            1       1.0      1.0   None  BdlSMOTE  RandomForest
# 3            1       1.0      1.0   None  BdlSMOTE      LightGBM
# 4            1       1.0      1.0   None  BdlSMOTE           SVC
#
#    train accuracy  train precision  train recall  train f1  train auc  \
# 0        0.843135         0.761502      0.999219  0.864313   0.843135
# 1        0.786239         0.700844      0.998828  0.823715   0.786239
# 2        0.896009         0.828209      0.999297  0.905745   0.896009
# 3        0.909091         0.846429      0.999531  0.916631   0.909091
# 4        0.569510         0.537354      0.999922  0.699044   0.569510
#
#    test accuracy  test precision  test recall   test f1  test auc
# 0       0.614226        0.003320     0.571429  0.006601  0.592875
# ...

# %%
df[df['test accuracy'] > 0.7].sort_values(['test auc', 'test recall'], ascending=False).head(40)
# Out:
#                   class_weight  null_del  encoded scaler            sampler  \
# RandomForest  {0: 0.005, 1: 1}       1.0      0.0   None           SVMSMOTE
# RandomForest  {0: 0.005, 1: 1}       1.0      0.0     MM           SVMSMOTE
# RandomForest  {0: 0.005, 1: 1}       1.0      0.0     SD           SVMSMOTE
# RandomForest  {0: 0.005, 1: 1}       1.0      0.0     RB           SVMSMOTE
# LogisticReg                NaN       0.0      1.0   None           SVMSMOTE
# LogisticReg                NaN       0.0      1.0   None           SVMSMOTE
# LogisticReg                NaN       1.0      1.0   None           SVMSMOTE
# LogisticReg                NaN       1.0      1.0   None           SVMSMOTE
# LogisticReg   {0: 0.005, 1: 1}       1.0      1.0     SD           SVMSMOTE
# 73                           1       0.0      0.0     SD           BdlSMOTE
# 2                            1       1.0      1.0   None           BdlSMOTE
# ...
